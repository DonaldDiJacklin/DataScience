# %%
import numpy as np
import matplotlib.pyplot as plt
from MyML import *

# %%
#normalize function
def normalize(x):
    for i in range(x.shape[1]):
        x[:,i] = (x[:,i]-min(x[:,i]))/(max(x[:,i]) - min(x[:,i]))
    return x

#One Hot Encoder
def OneHotEncode(x, columns):
    
    #New matrix to store result
    newMatrix = np.array([[]])
    
    #Iterate through every column
    for column in range(x.shape[1]):
        
        #Check to see if column is in list of specified columns. If so, one hot encode it.
        if column in columns:
            distinctValues = np.unique(x[:,column])
            encoded = np.zeros((x.shape[0],len(distinctValues)))
            print(encoded.shape)
            for item in range(x.shape[0]):
                for i in range(len(distinctValues)):
                    if x[item,column] == distinctValues[i]:
                        encoded[item,i] = 1
                        
        #If not in list of columns, store unedited column in "encoded".
        else:
            encoded = x[:,column].reshape((x.shape[0],1))
            
        #Sets newmatrix to result on first iteration
        if newMatrix.size == 0:
            newMatrix = encoded
            
        #Adds each column to the result. Works whether specified or not.
        else:
            newMatrix = np.hstack((newMatrix, encoded))
    return newMatrix

# %%
samples = 300
x1 = np.random.randn(1,2)*50
while 5 >= np.sqrt((x1[0,0]**2) + (x1[0,1]**2)) or 7 <= np.sqrt((x1[0,0]**2) + (x1[0,1]**2)):
    x1 = np.random.randn(1,2)*50
while x1.shape[0]<samples:
    x = np.random.randn(1,2)*50
    while 5 >= np.sqrt((x[0,0]**2) + (x[0,1]**2)) or 7 <= np.sqrt((x[0,0]**2) + (x[0,1]**2)):
        x = np.random.randn(1,2)*50
    x1 = np.vstack((x1,x))
x2 = np.random.randn(1,2)*2
while 2 >= np.sqrt((x2[0,0]**2) + (x2[0,1]**2)) or 3 <= np.sqrt((x2[0,0]**2) + (x2[0,1]**2)):
    x2 = np.random.randn(1,2)*2
while x2.shape[0]<samples:
    x = np.random.randn(1,2)*2
    while 2 >= (np.sqrt((x[0,0]**2) + (x[0,1]**2))) or 3 <= (np.sqrt((x[0,0]**2) + (x[0,1]**2))):
        x = np.random.randn(1,2)*2
    x2 = np.vstack((x2,x))
x3 = np.random.randn(samples,2)*(1/6)
x = np.vstack((x1,x2, x3))
x = normalize(x)
Y = np.vstack((np.zeros((samples,1)), np.ones((samples,1)), (np.ones((samples,1))+1)))
y = OneHotEncode(Y, [0])
rows = np.arange(x.shape[0]).reshape(x.shape[0],1)
np.random.shuffle(rows)
x = np.matrix(x[rows[:,0], :])
y = np.matrix(y[rows[:,0], :])
x = np.array(x)
y = np.array(y)
Y = np.matrix(Y[rows[:,0], :])
Y = np.array(Y)
plt.figure(figsize=(6,6))
plt.scatter(x[:,0], x[:,1], s = 4, alpha = .5, c = Y[:,0])
plt.suptitle("Not much, sup with you?", fontsize = 24)
plt.xlabel("x1", fontsize = 20)
plt.ylabel("x2", fontsize = 20)
plt.show()
# Out:
# (900, 3)

# %%
tanmodel = TSNN(indims = 2, nodes = [20,20,20,3], taskType = 'c')
tanmodel.train(x,y)
# relumodel = ml.tsnn(x.shape[1], [20,20,20,3], activation = ml.ReLU, derivActivations = ml.deReLU)
# Out:
# Weights not previously initialized. Initializing now.

# %%
lr = .0001
epochs = 1000
j = tanmodel.train(x,y, showAccuracy = True, lr = lr, epochs = epochs, weightScaling = True, NAG = False, mu = .1)
p = tanmodel.prediction
tandices = np.argmax(p, axis = 1)
tanpred = np.zeros((y.shape))
for i in range(len(tandices)):
    tanpred[i,tandices[i]]= 1
print(np.mean(tanpred == y)*100, "% accuracy")
print(min(j))
# Out:
# 55.55555555555556 % accuracy
# 1.0539764107337397

# %% [markdown]
# I tried TanH with varied learning rates and epochs, and always ran into a problem when it started to get close. I checked my code over and over again, and corroborated that it should work by checking with others in the group. My weight updates and theirs are nearly identical, and only tanh throws this error at me. So it's only after trying everything that I could think of that I have decided to proceed with the rest of the assignment without including the tanh network.

# %%
for i in range(5):
    lr = .00004
    epochs = 4000
    k = relumodel.train(x,y, showAccuracy = True, lr = lr, epochs = epochs, weightScaling = True, showPlot = False)
# Out:
# 100.0 % accuracy at iteration 874
# 100.0 % accuracy at iteration 2205
# 100.0 % accuracy at iteration 1460
# 100.0 % accuracy at iteration 1946
# 100.0 % accuracy at iteration 2571

# %%
for i in range(100):
    print("Mu:", i/100)
    lr = .00004
    epochs = 4000
    k = relumodel.train(x,y, showAccuracy = True, lr = lr, epochs = epochs, weightScaling = True, showPlot = False, NAG = True, mu = (i/100))
# Out:
# Mu: 0.0
# 100.0 % accuracy at iteration 957
# Mu: 0.01
# 100.0 % accuracy at iteration 1014
# Mu: 0.02
# 100.0 % accuracy at iteration 999
# Mu: 0.03
# 100.0 % accuracy at iteration 1002
# Mu: 0.04
# 100.0 % accuracy at iteration 1434
# Mu: 0.05
# 100.0 % accuracy at iteration 1006
# Mu: 0.06
# 100.0 % accuracy at iteration 1439
# Mu: 0.07
# 100.0 % accuracy at iteration 1181
# Mu: 0.08
# 100.0 % accuracy at iteration 1358
# Mu: 0.09
# 100.0 % accuracy at iteration 1305
# Mu: 0.1
# 100.0 % accuracy at iteration 1297
# Mu: 0.11
# 100.0 % accuracy at iteration 1053
# Mu: 0.12
# 100.0 % accuracy at iteration 790
# Mu: 0.13
# 100.0 % accuracy at iteration 2454
# Mu: 0.14
# 100.0 % accuracy at iteration 690
# Mu: 0.15
# 100.0 % accuracy at iteration 715
# Mu: 0.16
# 100.0 % accuracy at iteration 928
# Mu: 0.17
# 100.0 % accuracy at iteration 969
# Mu: 0.18
# 100.0 % accuracy at iteration 847
# Mu: 0.19
# 100.0 % accuracy at iteration 758
# Mu: 0.2
# 100.0 % accuracy at iteration 673
# Mu: 0.21
# 100.0 % accuracy at iteration 689
# Mu: 0.22
# 100.0 % accuracy at iteration 654
# Mu: 0.23
# 100.0 % accuracy at iteration 786
# Mu: 0.24
# 100.0 % accuracy at iteration 1469
# Mu: 0.25
# 100.0 % accuracy at iteration 620
# Mu: 0.26
# 100.0 % accuracy at iteration 853
# Mu: 0.27
# 100.0 % accuracy at iteration 812
# Mu: 0.28
# 100.0 % accuracy at iteration 1058
# Mu: 0.29
# 100.0 % accuracy at iteration 949
# Mu: 0.3
# 100.0 % accuracy at iteration 623
# Mu: 0.31
# 100.0 % accuracy at iteration 618
# Mu: 0.32
# 100.0 % accuracy at iteration 885
# Mu: 0.33
# 100.0 % accuracy at iteration 824
# Mu: 0.34
# 100.0 % accuracy at iteration 678
# Mu: 0.35
# 100.0 % accuracy at iteration 745
# Mu: 0.36
# 100.0 % accuracy at iteration 890
# Mu: 0.37
# 100.0 % accuracy at iteration 916
# Mu: 0.38
# 100.0 % accuracy at iteration 626
# Mu: 0.39
# 100.0 % accuracy at iteration 655
# Mu: 0.4
# 100.0 % accuracy at iteration 651
# Mu: 0.41
# 100.0 % accuracy at iteration 1294
# Mu: 0.42
# 100.0 % accuracy at iteration 1237
# Mu: 0.43
# 100.0 % accuracy at iteration 1039
# Mu: 0.44
# 100.0 % accuracy at iteration 472
# Mu: 0.45
# 100.0 % accuracy at iteration 573
# Mu: 0.46
# 100.0 % accuracy at iteration 747
# Mu: 0.47
# 100.0 % accuracy at iteration 422
# Mu: 0.48
# 100.0 % accuracy at iteration 658
# Mu: 0.49
# 100.0 % accuracy at iteration 624
# Mu: 0.5
# 100.0 % accuracy at iteration 1132
# Mu: 0.51
# 100.0 % accuracy at iteration 440
# Mu: 0.52
# 100.0 % accuracy at iteration 1395
# Mu: 0.53
# 100.0 % accuracy at iteration 580
# Mu: 0.54
# 100.0 % accuracy at iteration 1400
# Mu: 0.55
# 100.0 % accuracy at iteration 609
# Mu: 0.56
# 100.0 % accuracy at iteration 460
# Mu: 0.57
# 100.0 % accuracy at iteration 569
# Mu: 0.58
# 100.0 % accuracy at iteration 740
# Mu: 0.59
# 100.0 % accuracy at iteration 477
# Mu: 0.6
# 100.0 % accuracy at iteration 708
# Mu: 0.61
# 100.0 % accuracy at iteration 350
# Mu: 0.62
# 100.0 % accuracy at iteration 368
# Mu: 0.63
# 100.0 % accuracy at iteration 476
# Mu: 0.64
# 100.0 % accuracy at iteration 511
# Mu: 0.65
# 100.0 % accuracy at iteration 440
# Mu: 0.66
# 100.0 % accuracy at iteration 509
# Mu: 0.67
# 100.0 % accuracy at iteration 630
# Mu: 0.68
# 100.0 % accuracy at iteration 483
# Mu: 0.69
# 100.0 % accuracy at iteration 668
# Mu: 0.7
# 100.0 % accuracy at iteration 338
# Mu: 0.71
# 100.0 % accuracy at iteration 484
# Mu: 0.72
# 100.0 % accuracy at iteration 248
# Mu: 0.73
# 100.0 % accuracy at iteration 285
# Mu: 0.74
# 100.0 % accuracy at iteration 337
# Mu: 0.75
# 100.0 % accuracy at iteration 187
# Mu: 0.76
# 100.0 % accuracy at iteration 214
# Mu: 0.77
# 100.0 % accuracy at iteration 280
# Mu: 0.78
# 100.0 % accuracy at iteration 225
# Mu: 0.79
# 100.0 % accuracy at iteration 279
# Mu: 0.8
# 100.0 % accuracy at iteration 312
# Mu: 0.81
# 100.0 % accuracy at iteration 249
# Mu: 0.82
# 100.0 % accuracy at iteration 308
# Mu: 0.83
# 100.0 % accuracy at iteration 184
# Mu: 0.84
# 100.0 % accuracy at iteration 228
# Mu: 0.85
# 100.0 % accuracy at iteration 178
# Mu: 0.86
# 100.0 % accuracy at iteration 117
# Mu: 0.87
# 100.0 % accuracy at iteration 134
# Mu: 0.88
# 100.0 % accuracy at iteration 242
# Mu: 0.89
# 100.0 % accuracy at iteration 176
# Mu: 0.9
# 100.0 % accuracy at iteration 113
# Mu: 0.91
# 100.0 % accuracy at iteration 188
# Mu: 0.92
# 100.0 % accuracy at iteration 138
# Mu: 0.93
# 100.0 % accuracy at iteration 128
# Mu: 0.94
# 100.0 % accuracy at iteration 243
# Mu: 0.95
# 100.0 % accuracy at iteration 141
# Mu: 0.96
# 100.0 % accuracy at iteration 141
# Mu: 0.97
# 100.0 % accuracy at iteration 129
# Mu: 0.98
# 100.0 % accuracy at iteration 126
# Mu: 0.99
# 100.0 % accuracy at iteration 147

# %%
bestmu = .9
for i in range(5):
    lr = .00004
    epochs = 4000
    k = relumodel.train(x,y, showAccuracy = True, lr = lr, epochs = epochs, weightScaling = True, showPlot = False, NAG = True, mu = bestmu)
# Out:
# 100.0 % accuracy at iteration 292
# 100.0 % accuracy at iteration 150
# 100.0 % accuracy at iteration 202
# 100.0 % accuracy at iteration 176
# 100.0 % accuracy at iteration 192

# %%
np.mean([292,150,202,176,192])
# Out:
# 202.4

# %%
bestmu = .9
for i in range(5):
    lr = .00004
    epochs = 4000
    k = tanmodel.train(x,y, showAccuracy = True, lr = lr, epochs = epochs, weightScaling = True, showPlot = False, NAG = True, mu = bestmu)

# %% [markdown]
# As I stated before, my tanh never gets to 100% accuracy because it never converges. I tried running it with Nesterov momentum as a last-ditch effort, but still no dice.
