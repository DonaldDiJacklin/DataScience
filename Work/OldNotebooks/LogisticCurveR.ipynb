# %%
sig <- function(matrix){
    return(1/(1+exp(-matrix)))
}
X<- matrix(rnorm(5000*100), nrow = 5000, ncol = 100)
X<- cbind(rep(1,5000),X)

# %%
w<-as.matrix(rnorm(101))
Z <- X%*%w

# %%
P_hat <- sig(sort(Z))

# %%
plot(Z,P_hat, col = 'brown')
# Out:
# plot without title
