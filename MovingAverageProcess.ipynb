# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
Z = np.random.randn(1000)
X = []
for i in range(2,len(Z)):
    X.append(Z[i] + Z[i-1] +Z[i-2])

# %%
def autocorrelate(x,lag):
    if lag == 0:
        first = x
        last = x
    else:
        first = x[:-lag]
        last = x[(lag):]
    r = np.sum((first - np.mean(x))*(last - np.mean(x)))/np.sum((first - np.mean(x))**2)
    return(r)

# %%
correls = []
for i in range(31):
    correls.append(autocorrelate(X,i))

# %%
plt.bar(list(range(31)),correls)
# Out:
# <BarContainer object of 31 artists>

# %%
X = []
for i in range(3,len(Z)):
    X.append(Z[i] + Z[i-1] +Z[i-2]+Z[i-3])

# %%
correls = []
for i in range(31):
    correls.append(autocorrelate(X,i))

# %%
plt.bar(list(range(31)),correls)
# Out:
# <BarContainer object of 31 artists>

# %%
plt.plot(X)
